# %% [markdown]
# # Importing libraries
# https://www.kaggle.com/datasets/camnugent/california-housing-prices?resource=download

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data analysis
# - DataFrame: head, describe, info
# - Seaborn plots: pairplot and corr for all the DF, distplot of the price

# %%
housing_data = pd.read_csv("CAL_housing.csv")
housing_data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %% [markdown]
# Turning "ocean_proximity" into an dummy variable

# %%
housing_data["ocean_proximity"].unique()
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
housing_data["op-near_bay"] = housing_data["ocean_proximity"]=="NEAR BAY"
housing_data["op-1H_ocean"] = housing_data["ocean_proximity"]=="<1H OCEAN"
housing_data["op-inland"] = housing_data["ocean_proximity"]=="INLAND"
housing_data["op-near_ocean"] = housing_data["ocean_proximity"]=="NEAR OCEAN"
housing_data["op-island"] = housing_data["ocean_proximity"]=="ISLAND"

housing_data.drop("ocean_proximity", axis=1, inplace=True)

# %%
housing_data.columns
# Out:
# Index(['longitude', 'latitude', 'housing_median_age', 'total_rooms',
#        'total_bedrooms', 'population', 'households', 'median_income',
#        'median_house_value', 'op-near_bay', 'op-1H_ocean', 'op-inland',
#        'op-near_ocean', 'op-island'],
#       dtype='object')

# %%
housing_data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# ...

# %%
# sns.pairplot(data=housing_data)

# %% [markdown]
# # Machine Learning
# - List of features
# - List of predicted values (normally one item)
# - Train/Test split
# - Import and instantiate linear model
# - Apply fit model with the Train values

# %%
from sklearn.model_selection import train_test_split
X = housing_data[['longitude', 'latitude', 'housing_median_age', 'total_rooms',
    'total_bedrooms', 'population', 'households', 'median_income',
    'op-near_bay', 'op-1H_ocean', 'op-inland', 'op-near_ocean', 'op-island']]
y = housing_data['median_house_value']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
ln = LinearRegression()
ln.fit(X=X_train, y=y_train)
# Out:
# LinearRegression()

# %%
print(ln.intercept_)
# Out:
# -2276873.1633942225

# %%
coeff = pd.DataFrame(ln.coef_, X.columns, columns=["Coeff"])
coeff
# Out:
#                             Coeff
# longitude           -27032.548163
# latitude            -25434.398095
# housing_median_age    1076.924078
# total_rooms             -6.358013
# total_bedrooms         114.608705
# population             -36.431378
# households              32.655209
# median_income        39242.429478
# op-near_bay         -27548.010653
# op-1H_ocean         -21600.338516
# op-inland           -61641.199770
# op-near_ocean       -17933.113824
# op-island           128722.662763
